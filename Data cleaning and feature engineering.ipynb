# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

#读取训练集，并剔除无关变量
train = pd.read_csv("C:/Users/wangyajuan/Desktop/essay/dataset/train.csv")
train=train.drop(['Over18','StandardHours','EmployeeNumber'],axis=1)

for i in train.columns: 
    print('[' + i + ']' + ':') 
    print((train[train['Attrition'] == 1.0][i].value_counts()/train[i].value_counts()).sort_values(ascending = False)) #每个类型内离职占全部的比例并排序
    print('---------------------------------------------------------------------') 

sns.set_palette("Set2")#设置色板


table_bt=pd.crosstab(train.Education,train.Attrition)
table_bt.div(table_bt.sum(1).astype(float),axis=0).plot(kind='line')
plt.title('The percetage of Attrition in each type of Education')
plt.xlabel('Education')
plt.ylabel('Percentage')
plt.legend(frameon= True, fancybox = True,loc=1) 

table_bt=pd.crosstab(train.EnvironmentSatisfaction,train.Attrition)
table_bt.div(table_bt.sum(1).astype(float),axis=0).plot(kind='line')
plt.title('The percetage of Attrition in each type of EnvironmentSatisfaction')
plt.xlabel('EnvironmentSatisfaction')
plt.ylabel('Percentage')
plt.legend(frameon= True, fancybox = True,loc=1) 

table_bt=pd.crosstab(train.JobInvolvement,train.Attrition)
table_bt.div(table_bt.sum(1).astype(float),axis=0).plot(kind='line')
plt.title('The percetage of Attrition in each type of JobInvolvement')
plt.xlabel('JobInvolvement')
plt.ylabel('Percentage')
plt.legend(frameon= True, fancybox = True,loc=1) 

table_bt=pd.crosstab(train.JobLevel,train.Attrition)
table_bt.div(table_bt.sum(1).astype(float),axis=0).plot(kind='line')
plt.title('The percetage of Attrition in each type of JobLevel')
plt.xlabel('JobLevel')
plt.ylabel('Percentage')
plt.legend(frameon= True, fancybox = True,loc=1) 

table_bt=pd.crosstab(train.JobSatisfaction,train.Attrition)
table_bt.div(table_bt.sum(1).astype(float),axis=0).plot(kind='line')
plt.title('The percetage of Attrition in each type of JobSatisfaction')
plt.xlabel('JobSatisfaction')
plt.ylabel('Percentage')
plt.legend(frameon= True, fancybox = True,loc=1)

table_bt=pd.crosstab(train.PerformanceRating,train.Attrition)
table_bt.div(table_bt.sum(1).astype(float),axis=0).plot(kind='line')
plt.title('The percetage of Attrition in each type of PerformanceRating')
plt.xlabel('PerformanceRating')
plt.ylabel('Percentage')
plt.legend(frameon= True, fancybox = True,loc=1) 

table_bt=pd.crosstab(train.RelationshipSatisfaction,train.Attrition)
table_bt.div(table_bt.sum(1).astype(float),axis=0).plot(kind='line')
plt.title('The percetage of Attrition in each type of RelationshipSatisfaction')
plt.xlabel('RelationshipSatisfaction')
plt.ylabel('Percentage')
plt.legend(frameon= True, fancybox = True,loc=1) 

table_bt=pd.crosstab(train.StockOptionLevel,train.Attrition)
table_bt.div(table_bt.sum(1).astype(float),axis=0).plot(kind='line')
plt.title('The percetage of Attrition in each type of StockOptionLevel')
plt.xlabel('StockOptionLevel')
plt.ylabel('Percentage')
plt.legend(frameon= True, fancybox = True,loc=1) 

table_bt=pd.crosstab(train.WorkLifeBalance,train.Attrition)
table_bt.div(table_bt.sum(1).astype(float),axis=0).plot(kind='line')
plt.title('The percetage of Attrition in each type of WorkLifeBalance')
plt.xlabel('WorkLifeBalance')
plt.ylabel('Percentage')
plt.legend(frameon= True, fancybox = True,loc=1)
